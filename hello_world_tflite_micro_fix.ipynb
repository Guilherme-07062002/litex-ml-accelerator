# %% [markdown]
# # Train a Simple TensorFlow Lite for Microcontrollers model
#
# This notebook demonstrates the process of training a 2.5 kB model using TensorFlow and converting it for use with TensorFlow Lite for Microcontrollers.
#
# Deep learning networks learn to model patterns in underlying data. Here, we're going to train a network to model data generated by a [sine](https://en.wikipedia.org/wiki/Sine) function. This will result in a model that can take a value, `x`, and predict its sine, `y`.
#
# The model created in this notebook is used in the [hello_world](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world) example for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview).
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# ## Configure Defaults

# %%
# Define paths to model files
import os
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'model.keras'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'model.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'model.cc'

# %% [markdown]
# ## Setup Environment
#
# Install Dependencies

# %%
! pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.24.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %% [markdown]
# Import Dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf

# Keras is TensorFlow's high-level API for deep learning
from tensorflow import keras
# Numpy is a math library
import numpy as np
# Pandas is a data manipulation library
import pandas as pd
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# Math is Python's math library
import math

# Set seed for experiment reproducibility
seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### 1. Generate Data
#
# The code in the following cell will generate a set of random `x` values, calculate their sine values, and display them on a graph.

# %%
# Number of sample datapoints
SAMPLES = 4000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=4*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# Calculate the corresponding sine values
# y_values = np.sin(x_values).astype(np.float32)
y_values = (np.sin(x_values)+np.sin(x_values*2)).astype(np.float32)

# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 2. Add Noise
# Since it was generated directly by the sine function, our data fits a nice, smooth curve.
#
# However, machine learning models are good at extracting underlying meaning from messy, real world data. To demonstrate this, we can add some noise to our data to approximate something more life-like.
#
# In the following cell, we'll add some random noise to each value, then draw a new graph:

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 3. Split the Data
# We now have a noisy dataset that approximates real world data. We'll be using this to train our model.
#
# To evaluate the accuracy of the model we train, we'll need to compare its predictions to real data and check how well they match up. This evaluation happens during training (where it is referred to as validation) and after training (referred to as testing) It's important in both cases that we use fresh data that was not already used to train the model.
#
# The data is split as follows:
#   1. Training: 60%
#   2. Validation: 20%
#   3. Testing: 20%
#
# The following code will split our data and then plots each set as a different color:

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ### 1. Design the Model
# We're going to build a simple neural network model that will take an input value (in this case, `x`) and use it to predict a numeric output value (the sine of `x`). This type of problem is called a _regression_. It will use _layers_ of _neurons_ to attempt to learn any patterns underlying the training data, so it can make predictions.
#
# To begin with, we'll define two layers. The first layer takes a single input (our `x` value) and runs it through 8 neurons. Based on this input, each neuron will become _activated_ to a certain degree based on its internal state (its _weight_ and _bias_ values). A neuron's degree of activation is expressed as a number.
#
# The activation numbers from our first layer will be fed as inputs to our second layer, which is a single neuron. It will apply its own weights and bias to these inputs and calculate its own activation, which will be output as our `y` value.
#
# **Note:** To learn more about how neural networks function, you can explore the [Learn TensorFlow](https://codelabs.developers.google.com/codelabs/tensorflow-lab1-helloworld) codelabs.
#
# The code in the following cell defines our model using [Keras](https://www.tensorflow.org/guide/keras), TensorFlow's high-level API for creating deep learning networks. Once the network is defined, we _compile_ it, specifying parameters that determine how it will be trained:

# %%
# We'll use Keras to create a simple model architecture
model_1 = tf.keras.Sequential([
    # Add Input layer first (Keras 3 best practice)
    keras.layers.Input(shape=(1,)),

    # First layer takes a scalar input and feeds it through 8 "neurons". The
    # neurons decide whether to activate based on the 'relu' activation function.
    keras.layers.Dense(16, activation='relu'),
    
    keras.layers.Dense(16, activation='relu'),
    
    keras.layers.Dense(16, activation='relu'),

    # Final layer is a single neuron, since we want to output a single value
    keras.layers.Dense(1)
])

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model_1.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# ### 2. Train the Model
# Once we've defined the model, we can use our data to _train_ it. Training involves passing an `x` value into the neural network, checking how far the network's output deviates from the expected `y` value, and adjusting the neurons' weights and biases so that the output is more likely to be correct the next time.
#
# Training runs this process on the full dataset multiple times, and each full run-through is known as an _epoch_. The number of epochs to run during training is a parameter we can set.
#
# During each epoch, data is run through the network in multiple _batches_. Each batch, several pieces of data are passed into the network, producing output values. These outputs' correctness is measured in aggregate and the network's weights and biases are adjusted accordingly, once per batch. The _batch size_ is also a parameter we can set.
#
# The code in the following cell uses the `x` and `y` values from our training data to train the model. It runs for 500 _epochs_, with 64 pieces of data in each _batch_. We also pass in some data for _validation_. As you will see when you run the cell, training can take a while to complete:

# %%
# Train the model on our training data while validating on our validation set
history_1 = model_1.fit(x_train, y_train, epochs=250, batch_size=64,
                        validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/250
# 38/38 [==============================] - 1s 8ms/step - loss: 1.9173 - mae: 1.1195 - val_loss: 1.2397 - val_mae: 0.9010
# Epoch 2/250
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0871 - mae: 0.8277 - val_loss: 0.9686 - val_mae: 0.7867
# Epoch 3/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9356 - mae: 0.7685 - val_loss: 0.8918 - val_mae: 0.7536
# Epoch 4/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8701 - mae: 0.7428 - val_loss: 0.8417 - val_mae: 0.7329
# Epoch 5/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.8296 - mae: 0.7269 - val_loss: 0.8098 - val_mae: 0.7185
# Epoch 6/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8037 - mae: 0.7161 - val_loss: 0.7948 - val_mae: 0.7123
# Epoch 7/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7918 - mae: 0.7117 - val_loss: 0.7880 - val_mae: 0.7101
# Epoch 8/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7858 - mae: 0.7095 - val_loss: 0.7851 - val_mae: 0.7101
# Epoch 9/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7791 - mae: 0.7045 - val_loss: 0.7734 - val_mae: 0.6984
# Epoch 10/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7672 - mae: 0.6939 - val_loss: 0.7651 - val_mae: 0.6910
# Epoch 11/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7613 - mae: 0.6880 - val_loss: 0.7623 - val_mae: 0.6890
# Epoch 12/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7569 - mae: 0.6859 - val_loss: 0.7562 - val_mae: 0.6827
# Epoch 13/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7525 - mae: 0.6803 - val_loss: 0.7534 - val_mae: 0.6803
# Epoch 14/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7487 - mae: 0.6767 - val_loss: 0.7475 - val_mae: 0.6733
# Epoch 15/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7439 - mae: 0.6715 - val_loss: 0.7449 - val_mae: 0.6715
# Epoch 16/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7407 - mae: 0.6696 - val_loss: 0.7407 - val_mae: 0.6666
# Epoch 17/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7381 - mae: 0.6650 - val_loss: 0.7372 - val_mae: 0.6637
# Epoch 18/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7346 - mae: 0.6626 - val_loss: 0.7341 - val_mae: 0.6605
# Epoch 19/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7312 - mae: 0.6595 - val_loss: 0.7300 - val_mae: 0.6561
# Epoch 20/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7287 - mae: 0.6558 - val_loss: 0.7274 - val_mae: 0.6539
# Epoch 21/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7260 - mae: 0.6539 - val_loss: 0.7229 - val_mae: 0.6490
# Epoch 22/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7223 - mae: 0.6495 - val_loss: 0.7201 - val_mae: 0.6455
# Epoch 23/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7187 - mae: 0.6458 - val_loss: 0.7158 - val_mae: 0.6410
# Epoch 24/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7160 - mae: 0.6412 - val_loss: 0.7147 - val_mae: 0.6389
# Epoch 25/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7129 - mae: 0.6384 - val_loss: 0.7084 - val_mae: 0.6326
# Epoch 26/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7075 - mae: 0.6338 - val_loss: 0.7038 - val_mae: 0.6273
# Epoch 27/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7042 - mae: 0.6293 - val_loss: 0.7000 - val_mae: 0.6231
# Epoch 28/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7011 - mae: 0.6252 - val_loss: 0.6959 - val_mae: 0.6197
# Epoch 29/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6960 - mae: 0.6216 - val_loss: 0.6908 - val_mae: 0.6149
# Epoch 30/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6910 - mae: 0.6177 - val_loss: 0.6879 - val_mae: 0.6119
# Epoch 31/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6875 - mae: 0.6147 - val_loss: 0.6822 - val_mae: 0.6081
# Epoch 32/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6830 - mae: 0.6111 - val_loss: 0.6782 - val_mae: 0.6059
# Epoch 33/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6794 - mae: 0.6098 - val_loss: 0.6700 - val_mae: 0.5993
# Epoch 34/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6727 - mae: 0.6051 - val_loss: 0.6649 - val_mae: 0.5960
# Epoch 35/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6682 - mae: 0.6024 - val_loss: 0.6626 - val_mae: 0.5953
# Epoch 36/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6625 - mae: 0.5988 - val_loss: 0.6534 - val_mae: 0.5903
# Epoch 37/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6579 - mae: 0.5970 - val_loss: 0.6479 - val_mae: 0.5873
# Epoch 38/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6515 - mae: 0.5933 - val_loss: 0.6437 - val_mae: 0.5871
# Epoch 39/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6447 - mae: 0.5905 - val_loss: 0.6399 - val_mae: 0.5843
# Epoch 40/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6373 - mae: 0.5873 - val_loss: 0.6259 - val_mae: 0.5775
# Epoch 41/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6285 - mae: 0.5833 - val_loss: 0.6187 - val_mae: 0.5736
# Epoch 42/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6210 - mae: 0.5798 - val_loss: 0.6088 - val_mae: 0.5698
# Epoch 43/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6109 - mae: 0.5763 - val_loss: 0.5992 - val_mae: 0.5639
# Epoch 44/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6032 - mae: 0.5719 - val_loss: 0.5879 - val_mae: 0.5592
# Epoch 45/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5916 - mae: 0.5671 - val_loss: 0.5796 - val_mae: 0.5566
# Epoch 46/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5813 - mae: 0.5635 - val_loss: 0.5683 - val_mae: 0.5526
# Epoch 47/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5732 - mae: 0.5596 - val_loss: 0.5544 - val_mae: 0.5463
# Epoch 48/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5577 - mae: 0.5537 - val_loss: 0.5397 - val_mae: 0.5391
# Epoch 49/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5452 - mae: 0.5493 - val_loss: 0.5267 - val_mae: 0.5340
# Epoch 50/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5298 - mae: 0.5412 - val_loss: 0.5195 - val_mae: 0.5306
# Epoch 51/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5199 - mae: 0.5373 - val_loss: 0.4961 - val_mae: 0.5235
# Epoch 52/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4989 - mae: 0.5277 - val_loss: 0.4763 - val_mae: 0.5114
# Epoch 53/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.4839 - mae: 0.5220 - val_loss: 0.4572 - val_mae: 0.5021
# Epoch 54/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4670 - mae: 0.5126 - val_loss: 0.4546 - val_mae: 0.5019
# Epoch 55/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4453 - mae: 0.5034 - val_loss: 0.4206 - val_mae: 0.4857
# Epoch 56/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4235 - mae: 0.4940 - val_loss: 0.3997 - val_mae: 0.4766
# Epoch 57/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4071 - mae: 0.4860 - val_loss: 0.3775 - val_mae: 0.4644
# Epoch 58/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3835 - mae: 0.4727 - val_loss: 0.3588 - val_mae: 0.4541
# Epoch 59/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3616 - mae: 0.4617 - val_loss: 0.3485 - val_mae: 0.4486
# Epoch 60/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3503 - mae: 0.4571 - val_loss: 0.3260 - val_mae: 0.4365
# Epoch 61/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3274 - mae: 0.4453 - val_loss: 0.2977 - val_mae: 0.4265
# Epoch 62/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.3072 - mae: 0.4311 - val_loss: 0.2751 - val_mae: 0.4062
# Epoch 63/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2883 - mae: 0.4207 - val_loss: 0.2588 - val_mae: 0.3951
# Epoch 64/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2704 - mae: 0.4092 - val_loss: 0.2466 - val_mae: 0.3904
# Epoch 65/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2576 - mae: 0.4005 - val_loss: 0.2331 - val_mae: 0.3752
# Epoch 66/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2424 - mae: 0.3884 - val_loss: 0.2322 - val_mae: 0.3745
# Epoch 67/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2325 - mae: 0.3776 - val_loss: 0.2091 - val_mae: 0.3543
# Epoch 68/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2170 - mae: 0.3685 - val_loss: 0.2008 - val_mae: 0.3485
# Epoch 69/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.2066 - mae: 0.3587 - val_loss: 0.1888 - val_mae: 0.3398
# Epoch 70/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1995 - mae: 0.3518 - val_loss: 0.1750 - val_mae: 0.3273
# Epoch 71/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1946 - mae: 0.3449 - val_loss: 0.1676 - val_mae: 0.3191
# Epoch 72/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1900 - mae: 0.3408 - val_loss: 0.1646 - val_mae: 0.3153
# Epoch 73/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1803 - mae: 0.3305 - val_loss: 0.1619 - val_mae: 0.3106
# Epoch 74/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1739 - mae: 0.3230 - val_loss: 0.1549 - val_mae: 0.2981
# Epoch 75/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1734 - mae: 0.3216 - val_loss: 0.1493 - val_mae: 0.2945
# Epoch 76/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1660 - mae: 0.3127 - val_loss: 0.1462 - val_mae: 0.2897
# Epoch 77/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1612 - mae: 0.3049 - val_loss: 0.1528 - val_mae: 0.2955
# Epoch 78/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1631 - mae: 0.3058 - val_loss: 0.1404 - val_mae: 0.2807
# Epoch 79/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1568 - mae: 0.2986 - val_loss: 0.1391 - val_mae: 0.2782
# Epoch 80/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1544 - mae: 0.2958 - val_loss: 0.1390 - val_mae: 0.2776
# Epoch 81/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1570 - mae: 0.2956 - val_loss: 0.1400 - val_mae: 0.2740
# Epoch 82/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1531 - mae: 0.2918 - val_loss: 0.1408 - val_mae: 0.2809
# Epoch 83/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1507 - mae: 0.2879 - val_loss: 0.1350 - val_mae: 0.2691
# Epoch 84/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1490 - mae: 0.2863 - val_loss: 0.1331 - val_mae: 0.2655
# Epoch 85/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1484 - mae: 0.2841 - val_loss: 0.1318 - val_mae: 0.2639
# Epoch 86/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1475 - mae: 0.2819 - val_loss: 0.1345 - val_mae: 0.2706
# Epoch 87/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1468 - mae: 0.2818 - val_loss: 0.1385 - val_mae: 0.2688
# Epoch 88/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1516 - mae: 0.2845 - val_loss: 0.1340 - val_mae: 0.2654
# Epoch 89/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1465 - mae: 0.2786 - val_loss: 0.1299 - val_mae: 0.2605
# Epoch 90/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1455 - mae: 0.2786 - val_loss: 0.1319 - val_mae: 0.2650
# Epoch 91/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1449 - mae: 0.2775 - val_loss: 0.1301 - val_mae: 0.2584
# Epoch 92/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1488 - mae: 0.2782 - val_loss: 0.1295 - val_mae: 0.2563
# Epoch 93/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1454 - mae: 0.2760 - val_loss: 0.1282 - val_mae: 0.2563
# Epoch 94/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1445 - mae: 0.2750 - val_loss: 0.1297 - val_mae: 0.2599
# Epoch 95/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1432 - mae: 0.2729 - val_loss: 0.1343 - val_mae: 0.2616
# Epoch 96/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1449 - mae: 0.2752 - val_loss: 0.1336 - val_mae: 0.2655
# Epoch 97/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1428 - mae: 0.2726 - val_loss: 0.1338 - val_mae: 0.2618
# Epoch 98/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1484 - mae: 0.2764 - val_loss: 0.1294 - val_mae: 0.2584
# Epoch 99/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1427 - mae: 0.2709 - val_loss: 0.1287 - val_mae: 0.2562
# Epoch 100/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1456 - mae: 0.2733 - val_loss: 0.1275 - val_mae: 0.2537
# Epoch 101/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1423 - mae: 0.2701 - val_loss: 0.1269 - val_mae: 0.2525
# Epoch 102/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1468 - mae: 0.2749 - val_loss: 0.1285 - val_mae: 0.2516
# Epoch 103/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1427 - mae: 0.2700 - val_loss: 0.1267 - val_mae: 0.2509
# Epoch 104/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1431 - mae: 0.2720 - val_loss: 0.1290 - val_mae: 0.2567
# Epoch 105/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1459 - mae: 0.2737 - val_loss: 0.1288 - val_mae: 0.2529
# Epoch 106/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1426 - mae: 0.2695 - val_loss: 0.1289 - val_mae: 0.2556
# Epoch 107/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1438 - mae: 0.2725 - val_loss: 0.1284 - val_mae: 0.2541
# Epoch 108/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1414 - mae: 0.2679 - val_loss: 0.1301 - val_mae: 0.2563
# Epoch 109/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1442 - mae: 0.2722 - val_loss: 0.1269 - val_mae: 0.2518
# Epoch 110/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1447 - mae: 0.2723 - val_loss: 0.1304 - val_mae: 0.2585
# Epoch 111/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1462 - mae: 0.2743 - val_loss: 0.1267 - val_mae: 0.2494
# Epoch 112/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1418 - mae: 0.2680 - val_loss: 0.1264 - val_mae: 0.2507
# Epoch 113/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1439 - mae: 0.2696 - val_loss: 0.1266 - val_mae: 0.2485
# Epoch 114/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1425 - mae: 0.2683 - val_loss: 0.1322 - val_mae: 0.2622
# Epoch 115/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1420 - mae: 0.2685 - val_loss: 0.1259 - val_mae: 0.2493
# Epoch 116/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1410 - mae: 0.2669 - val_loss: 0.1269 - val_mae: 0.2511
# Epoch 117/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1417 - mae: 0.2675 - val_loss: 0.1285 - val_mae: 0.2560
# Epoch 118/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1417 - mae: 0.2677 - val_loss: 0.1261 - val_mae: 0.2497
# Epoch 119/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1448 - mae: 0.2719 - val_loss: 0.1292 - val_mae: 0.2578
# Epoch 120/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1414 - mae: 0.2683 - val_loss: 0.1262 - val_mae: 0.2489
# Epoch 121/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1407 - mae: 0.2663 - val_loss: 0.1256 - val_mae: 0.2473
# Epoch 122/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1406 - mae: 0.2658 - val_loss: 0.1256 - val_mae: 0.2467
# Epoch 123/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1407 - mae: 0.2658 - val_loss: 0.1268 - val_mae: 0.2480
# Epoch 124/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1411 - mae: 0.2664 - val_loss: 0.1257 - val_mae: 0.2479
# Epoch 125/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1407 - mae: 0.2675 - val_loss: 0.1271 - val_mae: 0.2487
# Epoch 126/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1411 - mae: 0.2659 - val_loss: 0.1255 - val_mae: 0.2475
# Epoch 127/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1406 - mae: 0.2650 - val_loss: 0.1293 - val_mae: 0.2494
# Epoch 128/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1410 - mae: 0.2672 - val_loss: 0.1256 - val_mae: 0.2475
# Epoch 129/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1413 - mae: 0.2661 - val_loss: 0.1274 - val_mae: 0.2502
# Epoch 130/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1434 - mae: 0.2697 - val_loss: 0.1298 - val_mae: 0.2500
# Epoch 131/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1420 - mae: 0.2673 - val_loss: 0.1276 - val_mae: 0.2534
# Epoch 132/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1413 - mae: 0.2673 - val_loss: 0.1264 - val_mae: 0.2467
# Epoch 133/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1424 - mae: 0.2680 - val_loss: 0.1288 - val_mae: 0.2475
# Epoch 134/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1407 - mae: 0.2651 - val_loss: 0.1275 - val_mae: 0.2475
# Epoch 135/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1436 - mae: 0.2694 - val_loss: 0.1277 - val_mae: 0.2529
# Epoch 136/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1426 - mae: 0.2683 - val_loss: 0.1272 - val_mae: 0.2523
# Epoch 137/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1431 - mae: 0.2695 - val_loss: 0.1282 - val_mae: 0.2565
# Epoch 138/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1416 - mae: 0.2666 - val_loss: 0.1256 - val_mae: 0.2470
# Epoch 139/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1396 - mae: 0.2634 - val_loss: 0.1271 - val_mae: 0.2471
# Epoch 140/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1477 - mae: 0.2744 - val_loss: 0.1300 - val_mae: 0.2564
# Epoch 141/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1421 - mae: 0.2688 - val_loss: 0.1265 - val_mae: 0.2503
# Epoch 142/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1403 - mae: 0.2652 - val_loss: 0.1274 - val_mae: 0.2467
# Epoch 143/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1407 - mae: 0.2649 - val_loss: 0.1262 - val_mae: 0.2482
# Epoch 144/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1413 - mae: 0.2670 - val_loss: 0.1272 - val_mae: 0.2475
# Epoch 145/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1408 - mae: 0.2657 - val_loss: 0.1318 - val_mae: 0.2636
# Epoch 146/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1450 - mae: 0.2710 - val_loss: 0.1255 - val_mae: 0.2474
# Epoch 147/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1405 - mae: 0.2653 - val_loss: 0.1266 - val_mae: 0.2485
# Epoch 148/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1404 - mae: 0.2652 - val_loss: 0.1275 - val_mae: 0.2493
# Epoch 149/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1421 - mae: 0.2672 - val_loss: 0.1287 - val_mae: 0.2476
# Epoch 150/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1422 - mae: 0.2674 - val_loss: 0.1256 - val_mae: 0.2474
# Epoch 151/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1417 - mae: 0.2662 - val_loss: 0.1253 - val_mae: 0.2458
# Epoch 152/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1425 - mae: 0.2683 - val_loss: 0.1262 - val_mae: 0.2479
# Epoch 153/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1410 - mae: 0.2663 - val_loss: 0.1263 - val_mae: 0.2457
# Epoch 154/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1441 - mae: 0.2690 - val_loss: 0.1357 - val_mae: 0.2675
# Epoch 155/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1441 - mae: 0.2726 - val_loss: 0.1266 - val_mae: 0.2503
# Epoch 156/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1405 - mae: 0.2642 - val_loss: 0.1254 - val_mae: 0.2459
# Epoch 157/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1414 - mae: 0.2678 - val_loss: 0.1274 - val_mae: 0.2469
# Epoch 158/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1400 - mae: 0.2649 - val_loss: 0.1269 - val_mae: 0.2494
# Epoch 159/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1415 - mae: 0.2674 - val_loss: 0.1263 - val_mae: 0.2457
# Epoch 160/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1399 - mae: 0.2643 - val_loss: 0.1273 - val_mae: 0.2479
# Epoch 161/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1415 - mae: 0.2662 - val_loss: 0.1266 - val_mae: 0.2508
# Epoch 162/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1409 - mae: 0.2648 - val_loss: 0.1258 - val_mae: 0.2465
# Epoch 163/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1404 - mae: 0.2648 - val_loss: 0.1295 - val_mae: 0.2555
# Epoch 164/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1449 - mae: 0.2716 - val_loss: 0.1256 - val_mae: 0.2474
# Epoch 165/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1409 - mae: 0.2655 - val_loss: 0.1262 - val_mae: 0.2495
# Epoch 166/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1402 - mae: 0.2638 - val_loss: 0.1316 - val_mae: 0.2572
# Epoch 167/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1423 - mae: 0.2695 - val_loss: 0.1282 - val_mae: 0.2508
# Epoch 168/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1440 - mae: 0.2719 - val_loss: 0.1260 - val_mae: 0.2481
# Epoch 169/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1406 - mae: 0.2657 - val_loss: 0.1250 - val_mae: 0.2464
# Epoch 170/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1398 - mae: 0.2630 - val_loss: 0.1271 - val_mae: 0.2476
# Epoch 171/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1406 - mae: 0.2662 - val_loss: 0.1263 - val_mae: 0.2473
# Epoch 172/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1390 - mae: 0.2631 - val_loss: 0.1264 - val_mae: 0.2479
# Epoch 173/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1445 - mae: 0.2705 - val_loss: 0.1369 - val_mae: 0.2671
# Epoch 174/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1417 - mae: 0.2667 - val_loss: 0.1258 - val_mae: 0.2460
# Epoch 175/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1424 - mae: 0.2664 - val_loss: 0.1283 - val_mae: 0.2570
# Epoch 176/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1421 - mae: 0.2684 - val_loss: 0.1292 - val_mae: 0.2580
# Epoch 177/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1411 - mae: 0.2657 - val_loss: 0.1249 - val_mae: 0.2459
# Epoch 178/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1415 - mae: 0.2672 - val_loss: 0.1332 - val_mae: 0.2581
# Epoch 179/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1446 - mae: 0.2741 - val_loss: 0.1257 - val_mae: 0.2489
# Epoch 180/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1415 - mae: 0.2660 - val_loss: 0.1278 - val_mae: 0.2457
# Epoch 181/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1420 - mae: 0.2661 - val_loss: 0.1282 - val_mae: 0.2544
# Epoch 182/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1434 - mae: 0.2714 - val_loss: 0.1304 - val_mae: 0.2504
# Epoch 183/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1393 - mae: 0.2635 - val_loss: 0.1293 - val_mae: 0.2496
# Epoch 184/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1420 - mae: 0.2658 - val_loss: 0.1260 - val_mae: 0.2483
# Epoch 185/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1408 - mae: 0.2646 - val_loss: 0.1259 - val_mae: 0.2462
# Epoch 186/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1408 - mae: 0.2653 - val_loss: 0.1251 - val_mae: 0.2452
# Epoch 187/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1426 - mae: 0.2690 - val_loss: 0.1367 - val_mae: 0.2675
# Epoch 188/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1425 - mae: 0.2719 - val_loss: 0.1274 - val_mae: 0.2525
# Epoch 189/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1411 - mae: 0.2663 - val_loss: 0.1255 - val_mae: 0.2456
# Epoch 190/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1413 - mae: 0.2660 - val_loss: 0.1253 - val_mae: 0.2462
# Epoch 191/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1412 - mae: 0.2650 - val_loss: 0.1313 - val_mae: 0.2569
# Epoch 192/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1408 - mae: 0.2663 - val_loss: 0.1263 - val_mae: 0.2500
# Epoch 193/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.1409 - mae: 0.2681 - val_loss: 0.1268 - val_mae: 0.2459
# Epoch 194/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1413 - mae: 0.2664 - val_loss: 0.1289 - val_mae: 0.2468
# Epoch 195/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1409 - mae: 0.2658 - val_loss: 0.1264 - val_mae: 0.2475
# Epoch 196/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1402 - mae: 0.2640 - val_loss: 0.1255 - val_mae: 0.2466
# Epoch 197/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1427 - mae: 0.2691 - val_loss: 0.1363 - val_mae: 0.2710
# Epoch 198/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1434 - mae: 0.2702 - val_loss: 0.1260 - val_mae: 0.2486
# Epoch 199/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1425 - mae: 0.2686 - val_loss: 0.1277 - val_mae: 0.2518
# Epoch 200/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1442 - mae: 0.2702 - val_loss: 0.1295 - val_mae: 0.2517
# Epoch 201/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1419 - mae: 0.2682 - val_loss: 0.1264 - val_mae: 0.2503
# Epoch 202/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1399 - mae: 0.2641 - val_loss: 0.1269 - val_mae: 0.2467
# Epoch 203/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1428 - mae: 0.2675 - val_loss: 0.1320 - val_mae: 0.2585
# Epoch 204/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1430 - mae: 0.2702 - val_loss: 0.1254 - val_mae: 0.2456
# Epoch 205/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1430 - mae: 0.2693 - val_loss: 0.1294 - val_mae: 0.2582
# Epoch 206/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1416 - mae: 0.2664 - val_loss: 0.1249 - val_mae: 0.2451
# Epoch 207/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1403 - mae: 0.2636 - val_loss: 0.1281 - val_mae: 0.2499
# Epoch 208/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1409 - mae: 0.2650 - val_loss: 0.1278 - val_mae: 0.2477
# Epoch 209/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1433 - mae: 0.2717 - val_loss: 0.1309 - val_mae: 0.2560
# Epoch 210/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1431 - mae: 0.2701 - val_loss: 0.1300 - val_mae: 0.2489
# Epoch 211/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1423 - mae: 0.2682 - val_loss: 0.1259 - val_mae: 0.2500
# Epoch 212/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1402 - mae: 0.2645 - val_loss: 0.1255 - val_mae: 0.2467
# Epoch 213/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1451 - mae: 0.2729 - val_loss: 0.1285 - val_mae: 0.2526
# Epoch 214/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1475 - mae: 0.2748 - val_loss: 0.1260 - val_mae: 0.2477
# Epoch 215/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1420 - mae: 0.2690 - val_loss: 0.1268 - val_mae: 0.2500
# Epoch 216/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1417 - mae: 0.2666 - val_loss: 0.1251 - val_mae: 0.2457
# Epoch 217/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1418 - mae: 0.2673 - val_loss: 0.1257 - val_mae: 0.2484
# Epoch 218/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1444 - mae: 0.2723 - val_loss: 0.1268 - val_mae: 0.2500
# Epoch 219/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1411 - mae: 0.2679 - val_loss: 0.1253 - val_mae: 0.2471
# Epoch 220/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1401 - mae: 0.2637 - val_loss: 0.1304 - val_mae: 0.2473
# Epoch 221/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1427 - mae: 0.2683 - val_loss: 0.1284 - val_mae: 0.2492
# Epoch 222/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1412 - mae: 0.2654 - val_loss: 0.1256 - val_mae: 0.2462
# Epoch 223/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1400 - mae: 0.2635 - val_loss: 0.1250 - val_mae: 0.2452
# Epoch 224/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1399 - mae: 0.2641 - val_loss: 0.1263 - val_mae: 0.2472
# Epoch 225/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1401 - mae: 0.2639 - val_loss: 0.1264 - val_mae: 0.2468
# Epoch 226/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1414 - mae: 0.2656 - val_loss: 0.1289 - val_mae: 0.2514
# Epoch 227/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1432 - mae: 0.2689 - val_loss: 0.1257 - val_mae: 0.2447
# Epoch 228/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1402 - mae: 0.2643 - val_loss: 0.1280 - val_mae: 0.2496
# Epoch 229/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1412 - mae: 0.2648 - val_loss: 0.1286 - val_mae: 0.2541
# Epoch 230/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1412 - mae: 0.2659 - val_loss: 0.1282 - val_mae: 0.2490
# Epoch 231/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1412 - mae: 0.2662 - val_loss: 0.1253 - val_mae: 0.2466
# Epoch 232/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1416 - mae: 0.2670 - val_loss: 0.1272 - val_mae: 0.2499
# Epoch 233/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1414 - mae: 0.2679 - val_loss: 0.1262 - val_mae: 0.2502
# Epoch 234/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1405 - mae: 0.2657 - val_loss: 0.1277 - val_mae: 0.2536
# Epoch 235/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1429 - mae: 0.2703 - val_loss: 0.1264 - val_mae: 0.2497
# Epoch 236/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1419 - mae: 0.2674 - val_loss: 0.1297 - val_mae: 0.2516
# Epoch 237/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1425 - mae: 0.2679 - val_loss: 0.1268 - val_mae: 0.2520
# Epoch 238/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1407 - mae: 0.2649 - val_loss: 0.1250 - val_mae: 0.2459
# Epoch 239/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1422 - mae: 0.2679 - val_loss: 0.1346 - val_mae: 0.2543
# Epoch 240/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1418 - mae: 0.2675 - val_loss: 0.1284 - val_mae: 0.2535
# Epoch 241/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1419 - mae: 0.2680 - val_loss: 0.1325 - val_mae: 0.2619
# Epoch 242/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1432 - mae: 0.2701 - val_loss: 0.1273 - val_mae: 0.2476
# Epoch 243/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1437 - mae: 0.2674 - val_loss: 0.1276 - val_mae: 0.2524
# Epoch 244/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1407 - mae: 0.2657 - val_loss: 0.1253 - val_mae: 0.2467
# Epoch 245/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1403 - mae: 0.2638 - val_loss: 0.1251 - val_mae: 0.2452
# Epoch 246/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1431 - mae: 0.2682 - val_loss: 0.1258 - val_mae: 0.2473
# Epoch 247/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1420 - mae: 0.2676 - val_loss: 0.1264 - val_mae: 0.2460
# Epoch 248/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1418 - mae: 0.2677 - val_loss: 0.1303 - val_mae: 0.2558
# Epoch 249/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1428 - mae: 0.2682 - val_loss: 0.1259 - val_mae: 0.2469
# Epoch 250/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.1431 - mae: 0.2674 - val_loss: 0.1321 - val_mae: 0.2627

# %% [markdown]
# ### 3. Plot Metrics

# %% [markdown]
# **1. Loss (or Mean Squared Error)**
#
# During training, the model's performance is constantly being measured against both our training data and the validation data that we set aside earlier. Training produces a log of data that tells us how the model's performance changed over the course of the training process.
#
# The following cells will display some of that data in a graphical form:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows the _loss_ (or the difference between the model's predictions and the actual data) for each epoch. There are several ways to calculate loss, and the method we have used is _mean squared error_. There is a distinct loss value given for the training and the validation data.
#
# As we can see, the amount of loss rapidly decreases over the first 25 epochs, before flattening out. This means that the model is improving and producing more accurate predictions!
#
# Our goal is to stop training when either the model is no longer improving, or when the _training loss_ is less than the _validation loss_, which would mean that the model has learned to predict the training data so well that it can no longer generalize to new data.
#
# To make the flatter part of the graph more readable, let's skip the first 50 epochs:

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 50

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# From the plot, we can see that loss continues to reduce until around 200 epochs, at which point it is mostly stable. This means that there's no need to train our network beyond 200 epochs.
#
# However, we can also see that the lowest loss value is still around 0.155. This means that our network's predictions are off by an average of ~15%. In addition, the validation loss values jump around a lot, and is sometimes even higher.
#
# **2. Mean Absolute Error**
#
# To gain more insight into our model's performance we can plot some more data. This time, we'll plot the _mean absolute error_, which is another way of measuring how far the network's predictions are from the actual numbers:

# %%
plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history_1.history['mae']
val_mae = history_1.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# This graph of _mean absolute error_ tells another story. We can see that training data shows consistently lower error than validation data, which means that the network may have _overfit_, or learned the training data so rigidly that it can't make effective predictions about new data.
#
# In addition, the mean absolute error values are quite high, ~0.305 at best, which means some of the model's predictions are at least 30% off. A 30% error means we are very far from accurately modelling the sine wave function.
#
# **3. Actual vs Predicted Outputs**
#
# To get more insight into what is happening, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model_1.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model_1.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predictions')
plt.legend()
plt.show()
# Out:
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1444 - mae: 0.2842
# 25/25 [==============================] - 0s 2ms/step

# %% [markdown]
# Oh dear! The graph makes it clear that our network has learned to approximate the sine function in a very limited way.
#
# The rigidity of this fit suggests that the model does not have enough capacity to learn the full complexity of the sine wave function, so it's only able to approximate it in an overly simplistic way. By making our model bigger, we should be able to improve its performance.

# %% [markdown]
# ## Training a Larger Model

# %% [markdown]
# ### 1. Design the Model
# To make our model bigger, let's add an additional layer of neurons. The following cell redefines our model in the same way as earlier, but with 16 neurons in the first layer and an additional layer of 16 neurons in the middle:

# %%
model = tf.keras.Sequential([
    # Add Input layer first (Keras 3 best practice)
    keras.layers.Input(shape=(1,)),

    # First layer takes a scalar input and feeds it through 16 "neurons". The
    # neurons decide whether to activate based on the 'relu' activation function.
    keras.layers.Dense(16, activation='relu'),

    # The new second and third layer will help the network learn more complex representations
    keras.layers.Dense(16, activation='relu'),

    # Final layer is a single neuron, since we want to output a single value
    keras.layers.Dense(1)
])

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model.compile(optimizer='adam', loss="mse", metrics=["mae"])

# %% [markdown]
# ### 2. Train the Model ###
#
# We'll now train and save the new model.

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=250, batch_size=64,
                    validation_data=(x_validate, y_validate))

# Save the model to disk
model.save(MODEL_TF)
print(MODEL_TF)
# Out:
# Epoch 1/250
# 38/38 [==============================] - 1s 6ms/step - loss: 0.9321 - mae: 0.7697 - val_loss: 0.9074 - val_mae: 0.7621
# Epoch 2/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8952 - mae: 0.7567 - val_loss: 0.8745 - val_mae: 0.7452
# Epoch 3/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8708 - mae: 0.7456 - val_loss: 0.8500 - val_mae: 0.7348
# Epoch 4/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8494 - mae: 0.7380 - val_loss: 0.8322 - val_mae: 0.7263
# Epoch 5/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.8342 - mae: 0.7322 - val_loss: 0.8266 - val_mae: 0.7220
# Epoch 6/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8271 - mae: 0.7286 - val_loss: 0.8179 - val_mae: 0.7213
# Epoch 7/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8194 - mae: 0.7257 - val_loss: 0.8076 - val_mae: 0.7120
# Epoch 8/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.8133 - mae: 0.7210 - val_loss: 0.8010 - val_mae: 0.7091
# Epoch 9/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.8078 - mae: 0.7184 - val_loss: 0.8052 - val_mae: 0.7143
# Epoch 10/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8048 - mae: 0.7166 - val_loss: 0.7906 - val_mae: 0.7025
# Epoch 11/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7987 - mae: 0.7151 - val_loss: 0.7876 - val_mae: 0.7016
# Epoch 12/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7939 - mae: 0.7109 - val_loss: 0.7818 - val_mae: 0.6969
# Epoch 13/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7865 - mae: 0.7046 - val_loss: 0.7774 - val_mae: 0.6934
# Epoch 14/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7827 - mae: 0.7025 - val_loss: 0.7752 - val_mae: 0.6936
# Epoch 15/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7785 - mae: 0.7002 - val_loss: 0.7690 - val_mae: 0.6883
# Epoch 16/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7724 - mae: 0.6957 - val_loss: 0.7737 - val_mae: 0.6868
# Epoch 17/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7694 - mae: 0.6925 - val_loss: 0.7610 - val_mae: 0.6805
# Epoch 18/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7652 - mae: 0.6895 - val_loss: 0.7597 - val_mae: 0.6782
# Epoch 19/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7616 - mae: 0.6863 - val_loss: 0.7521 - val_mae: 0.6752
# Epoch 20/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7578 - mae: 0.6827 - val_loss: 0.7489 - val_mae: 0.6733
# Epoch 21/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7562 - mae: 0.6823 - val_loss: 0.7475 - val_mae: 0.6728
# Epoch 22/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7506 - mae: 0.6764 - val_loss: 0.7409 - val_mae: 0.6664
# Epoch 23/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7443 - mae: 0.6719 - val_loss: 0.7393 - val_mae: 0.6621
# Epoch 24/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7398 - mae: 0.6667 - val_loss: 0.7340 - val_mae: 0.6600
# Epoch 25/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7397 - mae: 0.6652 - val_loss: 0.7320 - val_mae: 0.6582
# Epoch 26/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7349 - mae: 0.6629 - val_loss: 0.7346 - val_mae: 0.6545
# Epoch 27/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7323 - mae: 0.6589 - val_loss: 0.7251 - val_mae: 0.6501
# Epoch 28/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7281 - mae: 0.6555 - val_loss: 0.7300 - val_mae: 0.6490
# Epoch 29/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7281 - mae: 0.6528 - val_loss: 0.7204 - val_mae: 0.6444
# Epoch 30/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7249 - mae: 0.6510 - val_loss: 0.7184 - val_mae: 0.6428
# Epoch 31/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7249 - mae: 0.6486 - val_loss: 0.7172 - val_mae: 0.6398
# Epoch 32/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7196 - mae: 0.6435 - val_loss: 0.7227 - val_mae: 0.6450
# Epoch 33/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7196 - mae: 0.6427 - val_loss: 0.7178 - val_mae: 0.6408
# Epoch 34/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7182 - mae: 0.6417 - val_loss: 0.7128 - val_mae: 0.6359
# Epoch 35/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7174 - mae: 0.6402 - val_loss: 0.7128 - val_mae: 0.6331
# Epoch 36/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7217 - mae: 0.6400 - val_loss: 0.7122 - val_mae: 0.6345
# Epoch 37/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7148 - mae: 0.6364 - val_loss: 0.7094 - val_mae: 0.6311
# Epoch 38/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7129 - mae: 0.6348 - val_loss: 0.7084 - val_mae: 0.6294
# Epoch 39/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7126 - mae: 0.6330 - val_loss: 0.7101 - val_mae: 0.6306
# Epoch 40/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7123 - mae: 0.6319 - val_loss: 0.7086 - val_mae: 0.6287
# Epoch 41/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7125 - mae: 0.6321 - val_loss: 0.7079 - val_mae: 0.6275
# Epoch 42/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7125 - mae: 0.6317 - val_loss: 0.7072 - val_mae: 0.6263
# Epoch 43/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7110 - mae: 0.6307 - val_loss: 0.7063 - val_mae: 0.6238
# Epoch 44/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7099 - mae: 0.6284 - val_loss: 0.7055 - val_mae: 0.6232
# Epoch 45/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7093 - mae: 0.6283 - val_loss: 0.7060 - val_mae: 0.6240
# Epoch 46/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7099 - mae: 0.6286 - val_loss: 0.7064 - val_mae: 0.6220
# Epoch 47/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7124 - mae: 0.6286 - val_loss: 0.7054 - val_mae: 0.6226
# Epoch 48/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7096 - mae: 0.6271 - val_loss: 0.7063 - val_mae: 0.6231
# Epoch 49/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7097 - mae: 0.6267 - val_loss: 0.7045 - val_mae: 0.6212
# Epoch 50/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7107 - mae: 0.6272 - val_loss: 0.7050 - val_mae: 0.6211
# Epoch 51/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7139 - mae: 0.6288 - val_loss: 0.7043 - val_mae: 0.6201
# Epoch 52/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7109 - mae: 0.6269 - val_loss: 0.7037 - val_mae: 0.6189
# Epoch 53/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7082 - mae: 0.6254 - val_loss: 0.7039 - val_mae: 0.6180
# Epoch 54/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7086 - mae: 0.6252 - val_loss: 0.7066 - val_mae: 0.6193
# Epoch 55/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7102 - mae: 0.6256 - val_loss: 0.7095 - val_mae: 0.6225
# Epoch 56/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7084 - mae: 0.6238 - val_loss: 0.7051 - val_mae: 0.6188
# Epoch 57/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7094 - mae: 0.6241 - val_loss: 0.7030 - val_mae: 0.6164
# Epoch 58/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7080 - mae: 0.6242 - val_loss: 0.7080 - val_mae: 0.6177
# Epoch 59/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7070 - mae: 0.6229 - val_loss: 0.7030 - val_mae: 0.6159
# Epoch 60/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7096 - mae: 0.6233 - val_loss: 0.7062 - val_mae: 0.6163
# Epoch 61/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7149 - mae: 0.6273 - val_loss: 0.7026 - val_mae: 0.6147
# Epoch 62/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7133 - mae: 0.6234 - val_loss: 0.7027 - val_mae: 0.6148
# Epoch 63/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7114 - mae: 0.6247 - val_loss: 0.7057 - val_mae: 0.6172
# Epoch 64/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7100 - mae: 0.6221 - val_loss: 0.7033 - val_mae: 0.6146
# Epoch 65/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7103 - mae: 0.6220 - val_loss: 0.7076 - val_mae: 0.6178
# Epoch 66/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7091 - mae: 0.6218 - val_loss: 0.7021 - val_mae: 0.6128
# Epoch 67/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7079 - mae: 0.6195 - val_loss: 0.7051 - val_mae: 0.6158
# Epoch 68/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7057 - mae: 0.6189 - val_loss: 0.7175 - val_mae: 0.6243
# Epoch 69/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7101 - mae: 0.6224 - val_loss: 0.7035 - val_mae: 0.6139
# Epoch 70/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7098 - mae: 0.6213 - val_loss: 0.7019 - val_mae: 0.6117
# Epoch 71/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7126 - mae: 0.6224 - val_loss: 0.7075 - val_mae: 0.6168
# Epoch 72/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7122 - mae: 0.6217 - val_loss: 0.7022 - val_mae: 0.6121
# Epoch 73/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7140 - mae: 0.6220 - val_loss: 0.7055 - val_mae: 0.6160
# Epoch 74/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7066 - mae: 0.6192 - val_loss: 0.7018 - val_mae: 0.6116
# Epoch 75/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7069 - mae: 0.6205 - val_loss: 0.7148 - val_mae: 0.6176
# Epoch 76/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7162 - mae: 0.6235 - val_loss: 0.7037 - val_mae: 0.6114
# Epoch 77/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7068 - mae: 0.6201 - val_loss: 0.7050 - val_mae: 0.6141
# Epoch 78/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7088 - mae: 0.6199 - val_loss: 0.7018 - val_mae: 0.6103
# Epoch 79/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7080 - mae: 0.6208 - val_loss: 0.7028 - val_mae: 0.6107
# Epoch 80/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7072 - mae: 0.6190 - val_loss: 0.7042 - val_mae: 0.6136
# Epoch 81/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7092 - mae: 0.6207 - val_loss: 0.7026 - val_mae: 0.6105
# Epoch 82/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7116 - mae: 0.6210 - val_loss: 0.7042 - val_mae: 0.6142
# Epoch 83/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7088 - mae: 0.6200 - val_loss: 0.7043 - val_mae: 0.6132
# Epoch 84/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7077 - mae: 0.6195 - val_loss: 0.7018 - val_mae: 0.6101
# Epoch 85/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7096 - mae: 0.6192 - val_loss: 0.7081 - val_mae: 0.6159
# Epoch 86/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7167 - mae: 0.6233 - val_loss: 0.7018 - val_mae: 0.6101
# Epoch 87/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7065 - mae: 0.6181 - val_loss: 0.7016 - val_mae: 0.6101
# Epoch 88/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7083 - mae: 0.6186 - val_loss: 0.7052 - val_mae: 0.6143
# Epoch 89/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7072 - mae: 0.6188 - val_loss: 0.7019 - val_mae: 0.6100
# Epoch 90/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7070 - mae: 0.6189 - val_loss: 0.7033 - val_mae: 0.6103
# Epoch 91/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7069 - mae: 0.6181 - val_loss: 0.7041 - val_mae: 0.6133
# Epoch 92/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7097 - mae: 0.6227 - val_loss: 0.7016 - val_mae: 0.6105
# Epoch 93/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7047 - mae: 0.6188 - val_loss: 0.7095 - val_mae: 0.6134
# Epoch 94/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7102 - mae: 0.6200 - val_loss: 0.7016 - val_mae: 0.6105
# Epoch 95/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7091 - mae: 0.6192 - val_loss: 0.7017 - val_mae: 0.6106
# Epoch 96/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7088 - mae: 0.6176 - val_loss: 0.7110 - val_mae: 0.6173
# Epoch 97/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7103 - mae: 0.6217 - val_loss: 0.7016 - val_mae: 0.6101
# Epoch 98/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7056 - mae: 0.6167 - val_loss: 0.7075 - val_mae: 0.6149
# Epoch 99/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7078 - mae: 0.6181 - val_loss: 0.7026 - val_mae: 0.6113
# Epoch 100/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7072 - mae: 0.6187 - val_loss: 0.7021 - val_mae: 0.6098
# Epoch 101/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7074 - mae: 0.6181 - val_loss: 0.7016 - val_mae: 0.6099
# Epoch 102/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7065 - mae: 0.6174 - val_loss: 0.7034 - val_mae: 0.6118
# Epoch 103/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7076 - mae: 0.6183 - val_loss: 0.7018 - val_mae: 0.6094
# Epoch 104/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7046 - mae: 0.6186 - val_loss: 0.7136 - val_mae: 0.6181
# Epoch 105/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7126 - mae: 0.6185 - val_loss: 0.7015 - val_mae: 0.6100
# Epoch 106/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7066 - mae: 0.6169 - val_loss: 0.7168 - val_mae: 0.6207
# Epoch 107/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7118 - mae: 0.6204 - val_loss: 0.7031 - val_mae: 0.6114
# Epoch 108/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7056 - mae: 0.6178 - val_loss: 0.7071 - val_mae: 0.6122
# Epoch 109/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7079 - mae: 0.6181 - val_loss: 0.7020 - val_mae: 0.6095
# Epoch 110/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7116 - mae: 0.6213 - val_loss: 0.7024 - val_mae: 0.6113
# Epoch 111/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7091 - mae: 0.6194 - val_loss: 0.7028 - val_mae: 0.6113
# Epoch 112/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7074 - mae: 0.6189 - val_loss: 0.7039 - val_mae: 0.6126
# Epoch 113/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7085 - mae: 0.6191 - val_loss: 0.7015 - val_mae: 0.6098
# Epoch 114/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7070 - mae: 0.6187 - val_loss: 0.7022 - val_mae: 0.6105
# Epoch 115/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7104 - mae: 0.6192 - val_loss: 0.7022 - val_mae: 0.6105
# Epoch 116/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7051 - mae: 0.6178 - val_loss: 0.7028 - val_mae: 0.6096
# Epoch 117/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7061 - mae: 0.6173 - val_loss: 0.7024 - val_mae: 0.6093
# Epoch 118/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7081 - mae: 0.6171 - val_loss: 0.7018 - val_mae: 0.6104
# Epoch 119/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7075 - mae: 0.6175 - val_loss: 0.7056 - val_mae: 0.6133
# Epoch 120/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7082 - mae: 0.6183 - val_loss: 0.7015 - val_mae: 0.6096
# Epoch 121/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7058 - mae: 0.6168 - val_loss: 0.7017 - val_mae: 0.6100
# Epoch 122/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7092 - mae: 0.6187 - val_loss: 0.7025 - val_mae: 0.6114
# Epoch 123/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7073 - mae: 0.6180 - val_loss: 0.7016 - val_mae: 0.6099
# Epoch 124/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7063 - mae: 0.6178 - val_loss: 0.7013 - val_mae: 0.6093
# Epoch 125/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7082 - mae: 0.6183 - val_loss: 0.7034 - val_mae: 0.6115
# Epoch 126/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7050 - mae: 0.6168 - val_loss: 0.6972 - val_mae: 0.6074
# Epoch 127/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7025 - mae: 0.6159 - val_loss: 0.6962 - val_mae: 0.6072
# Epoch 128/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7018 - mae: 0.6148 - val_loss: 0.7031 - val_mae: 0.6129
# Epoch 129/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7009 - mae: 0.6162 - val_loss: 0.6947 - val_mae: 0.6066
# Epoch 130/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6990 - mae: 0.6141 - val_loss: 0.6941 - val_mae: 0.6067
# Epoch 131/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6995 - mae: 0.6150 - val_loss: 0.6926 - val_mae: 0.6056
# Epoch 132/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6974 - mae: 0.6127 - val_loss: 0.6900 - val_mae: 0.6037
# Epoch 133/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6958 - mae: 0.6130 - val_loss: 0.6881 - val_mae: 0.6030
# Epoch 134/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6931 - mae: 0.6123 - val_loss: 0.6866 - val_mae: 0.6013
# Epoch 135/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6903 - mae: 0.6097 - val_loss: 0.6853 - val_mae: 0.6019
# Epoch 136/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6884 - mae: 0.6083 - val_loss: 0.6860 - val_mae: 0.6039
# Epoch 137/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6878 - mae: 0.6087 - val_loss: 0.6780 - val_mae: 0.5976
# Epoch 138/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.6830 - mae: 0.6052 - val_loss: 0.6757 - val_mae: 0.5974
# Epoch 139/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6816 - mae: 0.6058 - val_loss: 0.6720 - val_mae: 0.5946
# Epoch 140/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6762 - mae: 0.6043 - val_loss: 0.6676 - val_mae: 0.5941
# Epoch 141/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6737 - mae: 0.6025 - val_loss: 0.6635 - val_mae: 0.5920
# Epoch 142/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6684 - mae: 0.5994 - val_loss: 0.6620 - val_mae: 0.5924
# Epoch 143/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6633 - mae: 0.5970 - val_loss: 0.6568 - val_mae: 0.5902
# Epoch 144/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6609 - mae: 0.5967 - val_loss: 0.6532 - val_mae: 0.5869
# Epoch 145/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6579 - mae: 0.5949 - val_loss: 0.6586 - val_mae: 0.5964
# Epoch 146/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6558 - mae: 0.5975 - val_loss: 0.6475 - val_mae: 0.5891
# Epoch 147/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6482 - mae: 0.5927 - val_loss: 0.6345 - val_mae: 0.5803
# Epoch 148/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6420 - mae: 0.5902 - val_loss: 0.6297 - val_mae: 0.5779
# Epoch 149/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6356 - mae: 0.5866 - val_loss: 0.6310 - val_mae: 0.5832
# Epoch 150/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6314 - mae: 0.5869 - val_loss: 0.6164 - val_mae: 0.5720
# Epoch 151/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6243 - mae: 0.5837 - val_loss: 0.6190 - val_mae: 0.5772
# Epoch 152/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6195 - mae: 0.5823 - val_loss: 0.6072 - val_mae: 0.5718
# Epoch 153/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6131 - mae: 0.5800 - val_loss: 0.5996 - val_mae: 0.5676
# Epoch 154/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6071 - mae: 0.5771 - val_loss: 0.5941 - val_mae: 0.5631
# Epoch 155/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6029 - mae: 0.5763 - val_loss: 0.5879 - val_mae: 0.5613
# Epoch 156/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5976 - mae: 0.5741 - val_loss: 0.5861 - val_mae: 0.5659
# Epoch 157/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5937 - mae: 0.5746 - val_loss: 0.5841 - val_mae: 0.5619
# Epoch 158/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5916 - mae: 0.5732 - val_loss: 0.5716 - val_mae: 0.5575
# Epoch 159/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5833 - mae: 0.5705 - val_loss: 0.5660 - val_mae: 0.5533
# Epoch 160/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5782 - mae: 0.5686 - val_loss: 0.5610 - val_mae: 0.5550
# Epoch 161/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5738 - mae: 0.5666 - val_loss: 0.5560 - val_mae: 0.5542
# Epoch 162/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5684 - mae: 0.5669 - val_loss: 0.5540 - val_mae: 0.5565
# Epoch 163/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5674 - mae: 0.5683 - val_loss: 0.5480 - val_mae: 0.5525
# Epoch 164/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5608 - mae: 0.5636 - val_loss: 0.5492 - val_mae: 0.5441
# Epoch 165/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5614 - mae: 0.5658 - val_loss: 0.5401 - val_mae: 0.5501
# Epoch 166/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5552 - mae: 0.5614 - val_loss: 0.5350 - val_mae: 0.5489
# Epoch 167/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5496 - mae: 0.5610 - val_loss: 0.5367 - val_mae: 0.5529
# Epoch 168/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5464 - mae: 0.5603 - val_loss: 0.5286 - val_mae: 0.5429
# Epoch 169/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5450 - mae: 0.5595 - val_loss: 0.5241 - val_mae: 0.5444
# Epoch 170/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5409 - mae: 0.5570 - val_loss: 0.5335 - val_mae: 0.5586
# Epoch 171/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5423 - mae: 0.5609 - val_loss: 0.5235 - val_mae: 0.5456
# Epoch 172/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5368 - mae: 0.5569 - val_loss: 0.5210 - val_mae: 0.5494
# Epoch 173/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5356 - mae: 0.5582 - val_loss: 0.5135 - val_mae: 0.5402
# Epoch 174/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5339 - mae: 0.5581 - val_loss: 0.5117 - val_mae: 0.5443
# Epoch 175/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5318 - mae: 0.5567 - val_loss: 0.5090 - val_mae: 0.5437
# Epoch 176/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5314 - mae: 0.5582 - val_loss: 0.5076 - val_mae: 0.5393
# Epoch 177/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5258 - mae: 0.5529 - val_loss: 0.5067 - val_mae: 0.5447
# Epoch 178/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5254 - mae: 0.5529 - val_loss: 0.5099 - val_mae: 0.5473
# Epoch 179/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5260 - mae: 0.5555 - val_loss: 0.5028 - val_mae: 0.5383
# Epoch 180/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5222 - mae: 0.5532 - val_loss: 0.5025 - val_mae: 0.5430
# Epoch 181/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5198 - mae: 0.5530 - val_loss: 0.4986 - val_mae: 0.5382
# Epoch 182/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5213 - mae: 0.5556 - val_loss: 0.4980 - val_mae: 0.5386
# Epoch 183/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5177 - mae: 0.5505 - val_loss: 0.4984 - val_mae: 0.5429
# Epoch 184/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5176 - mae: 0.5524 - val_loss: 0.4954 - val_mae: 0.5395
# Epoch 185/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5199 - mae: 0.5534 - val_loss: 0.4949 - val_mae: 0.5413
# Epoch 186/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5147 - mae: 0.5519 - val_loss: 0.4926 - val_mae: 0.5389
# Epoch 187/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5134 - mae: 0.5529 - val_loss: 0.4959 - val_mae: 0.5393
# Epoch 188/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5164 - mae: 0.5519 - val_loss: 0.4974 - val_mae: 0.5417
# Epoch 189/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5123 - mae: 0.5517 - val_loss: 0.4895 - val_mae: 0.5353
# Epoch 190/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5135 - mae: 0.5513 - val_loss: 0.4885 - val_mae: 0.5352
# Epoch 191/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5141 - mae: 0.5513 - val_loss: 0.4889 - val_mae: 0.5371
# Epoch 192/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5117 - mae: 0.5496 - val_loss: 0.4922 - val_mae: 0.5412
# Epoch 193/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5114 - mae: 0.5513 - val_loss: 0.4869 - val_mae: 0.5368
# Epoch 194/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5134 - mae: 0.5516 - val_loss: 0.5022 - val_mae: 0.5462
# Epoch 195/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5160 - mae: 0.5551 - val_loss: 0.4882 - val_mae: 0.5413
# Epoch 196/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5113 - mae: 0.5503 - val_loss: 0.4930 - val_mae: 0.5420
# Epoch 197/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5113 - mae: 0.5518 - val_loss: 0.4902 - val_mae: 0.5414
# Epoch 198/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5111 - mae: 0.5522 - val_loss: 0.4863 - val_mae: 0.5330
# Epoch 199/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5111 - mae: 0.5519 - val_loss: 0.4883 - val_mae: 0.5406
# Epoch 200/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5083 - mae: 0.5504 - val_loss: 0.4885 - val_mae: 0.5360
# Epoch 201/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5081 - mae: 0.5515 - val_loss: 0.4933 - val_mae: 0.5420
# Epoch 202/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5093 - mae: 0.5509 - val_loss: 0.4885 - val_mae: 0.5408
# Epoch 203/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5110 - mae: 0.5514 - val_loss: 0.4836 - val_mae: 0.5358
# Epoch 204/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5102 - mae: 0.5515 - val_loss: 0.4842 - val_mae: 0.5361
# Epoch 205/250
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5106 - mae: 0.5540 - val_loss: 0.4848 - val_mae: 0.5382
# Epoch 206/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5064 - mae: 0.5499 - val_loss: 0.4825 - val_mae: 0.5349
# Epoch 207/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5080 - mae: 0.5499 - val_loss: 0.4831 - val_mae: 0.5376
# Epoch 208/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5056 - mae: 0.5478 - val_loss: 0.4896 - val_mae: 0.5413
# Epoch 209/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5128 - mae: 0.5559 - val_loss: 0.4839 - val_mae: 0.5371
# Epoch 210/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5129 - mae: 0.5539 - val_loss: 0.4816 - val_mae: 0.5347
# Epoch 211/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5052 - mae: 0.5496 - val_loss: 0.4805 - val_mae: 0.5344
# Epoch 212/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5044 - mae: 0.5497 - val_loss: 0.4832 - val_mae: 0.5387
# Epoch 213/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5075 - mae: 0.5520 - val_loss: 0.4816 - val_mae: 0.5331
# Epoch 214/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5054 - mae: 0.5480 - val_loss: 0.4808 - val_mae: 0.5337
# Epoch 215/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5064 - mae: 0.5494 - val_loss: 0.4802 - val_mae: 0.5340
# Epoch 216/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5052 - mae: 0.5491 - val_loss: 0.4830 - val_mae: 0.5399
# Epoch 217/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5104 - mae: 0.5530 - val_loss: 0.4817 - val_mae: 0.5371
# Epoch 218/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5047 - mae: 0.5485 - val_loss: 0.4795 - val_mae: 0.5322
# Epoch 219/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5044 - mae: 0.5484 - val_loss: 0.4810 - val_mae: 0.5362
# Epoch 220/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5051 - mae: 0.5493 - val_loss: 0.4826 - val_mae: 0.5378
# Epoch 221/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5088 - mae: 0.5533 - val_loss: 0.4845 - val_mae: 0.5367
# Epoch 222/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5049 - mae: 0.5488 - val_loss: 0.4794 - val_mae: 0.5315
# Epoch 223/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5043 - mae: 0.5491 - val_loss: 0.4804 - val_mae: 0.5302
# Epoch 224/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5085 - mae: 0.5505 - val_loss: 0.4786 - val_mae: 0.5331
# Epoch 225/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5037 - mae: 0.5487 - val_loss: 0.4828 - val_mae: 0.5379
# Epoch 226/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5063 - mae: 0.5508 - val_loss: 0.4787 - val_mae: 0.5329
# Epoch 227/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5064 - mae: 0.5520 - val_loss: 0.4789 - val_mae: 0.5331
# Epoch 228/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5057 - mae: 0.5491 - val_loss: 0.4815 - val_mae: 0.5343
# Epoch 229/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5059 - mae: 0.5513 - val_loss: 0.4860 - val_mae: 0.5385
# Epoch 230/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5050 - mae: 0.5493 - val_loss: 0.4832 - val_mae: 0.5394
# Epoch 231/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5039 - mae: 0.5498 - val_loss: 0.4792 - val_mae: 0.5343
# Epoch 232/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5035 - mae: 0.5479 - val_loss: 0.4928 - val_mae: 0.5447
# Epoch 233/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5063 - mae: 0.5498 - val_loss: 0.4832 - val_mae: 0.5363
# Epoch 234/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5026 - mae: 0.5491 - val_loss: 0.4783 - val_mae: 0.5292
# Epoch 235/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5051 - mae: 0.5490 - val_loss: 0.4790 - val_mae: 0.5330
# Epoch 236/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5058 - mae: 0.5506 - val_loss: 0.4785 - val_mae: 0.5319
# Epoch 237/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5078 - mae: 0.5507 - val_loss: 0.4798 - val_mae: 0.5348
# Epoch 238/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5090 - mae: 0.5528 - val_loss: 0.4792 - val_mae: 0.5354
# Epoch 239/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5071 - mae: 0.5517 - val_loss: 0.4785 - val_mae: 0.5318
# Epoch 240/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5075 - mae: 0.5498 - val_loss: 0.4803 - val_mae: 0.5303
# Epoch 241/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5076 - mae: 0.5506 - val_loss: 0.4782 - val_mae: 0.5331
# Epoch 242/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5035 - mae: 0.5478 - val_loss: 0.4809 - val_mae: 0.5358
# Epoch 243/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5035 - mae: 0.5487 - val_loss: 0.4812 - val_mae: 0.5369
# Epoch 244/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5050 - mae: 0.5497 - val_loss: 0.4820 - val_mae: 0.5390
# Epoch 245/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5050 - mae: 0.5512 - val_loss: 0.4862 - val_mae: 0.5419
# Epoch 246/250
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5058 - mae: 0.5508 - val_loss: 0.4810 - val_mae: 0.5341
# Epoch 247/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5055 - mae: 0.5472 - val_loss: 0.4970 - val_mae: 0.5492
# Epoch 248/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5078 - mae: 0.5545 - val_loss: 0.4877 - val_mae: 0.5367
# Epoch 249/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5093 - mae: 0.5540 - val_loss: 0.4818 - val_mae: 0.5404
# Epoch 250/250
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5058 - mae: 0.5504 - val_loss: 0.4786 - val_mae: 0.5332
# models/model.keras

# %% [markdown]
# ### 3. Plot Metrics
# Each training epoch, the model prints out its loss and mean absolute error for training and validation. You can read this in the output above (note that your exact numbers may differ):
#
# ```
# Epoch 500/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0121 - mae: 0.0882 - val_loss: 0.0115 - val_mae: 0.0865
# ```
#
# You can see that we've already got a huge improvement - validation loss has dropped from 0.15 to 0.01, and validation MAE has dropped from 0.33 to 0.08.
#
# The following cell will print the same graphs we used to evaluate our original model, but showing our new training history:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 400

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()

# %% [markdown]
# Great results! From these graphs, we can see several exciting things:
#
# *   The overall loss and MAE are much better than our previous network
# *   Metrics are better for validation than training, which means the network is not overfitting
#
# The reason the metrics for validation are better than those for training is that validation metrics are calculated at the end of each epoch, while training metrics are calculated throughout the epoch, so validation happens on a model that has been trained slightly longer.
#
# This all means our network seems to be performing well! To confirm, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predicted')
plt.legend()
plt.show()
# Out:
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4861 - mae: 0.5401
# 25/25 [==============================] - 0s 2ms/step

# %% [markdown]
# Much better! The evaluation metrics we printed show that the model has a low loss and MAE on the test data, and the predictions line up visually with our data fairly well.
#
# The model isn't perfect; its predictions don't form a smooth sine curve. For instance, the line is almost straight when `x` is between 4.2 and 5.2. If we wanted to go further, we could try further increasing the capacity of the model, perhaps using some techniques to defend from overfitting.
#
# However, an important part of machine learning is *knowing when to stop*. This model is good enough for our use case - which is to make some LEDs blink in a pleasing pattern.
#
# ## Generate a TensorFlow Lite Model

# %% [markdown]
# ### 1. Generate Models with or without Quantization
# We now have an acceptably accurate model. We'll use the [TensorFlow Lite Converter](https://www.tensorflow.org/lite/convert) to convert the model into a special, space-efficient format for use on memory-constrained devices.
#
# Since this model is going to be deployed on a microcontroller, we want it to be as tiny as possible! One technique for reducing the size of a model is called [quantization](https://www.tensorflow.org/lite/performance/post_training_quantization). It reduces the precision of the model's weights, and possibly the activations (output of each layer) as well, which saves memory, often without much impact on accuracy. Quantized models also run faster, since the calculations required are simpler.
#
# In the following cell, we'll convert the model twice: once with quantization, once without.

# %%
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(MODEL_NO_QUANT_TFLITE, "wb").write(model_no_quant_tflite)

# Convert the model to the TensorFlow Lite format with quantization
def representative_dataset():
  for i in range(500):
    yield([x_train[i].reshape(1, 1)])
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_TFLITE, "wb").write(model_tflite)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp_vej583h/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_vej583h/assets
# 2025-11-29 19:53:36.421319: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-29 19:53:36.421465: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2025-11-29 19:53:36.423410: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp_vej583h
# 2025-11-29 19:53:36.425759: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2025-11-29 19:53:36.425783: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp_vej583h
# 2025-11-29 19:53:36.434063: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2025-11-29 19:53:36.490729: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp_vej583h
# 2025-11-29 19:53:36.501561: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 78068 microseconds.
# INFO:tensorflow:Assets written to: /tmp/tmp1wdw0oap/assets
# INFO:tensorflow:Assets written to: /tmp/tmp1wdw0oap/assets
# /opt/conda/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2025-11-29 19:53:37.538236: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-29 19:53:37.538297: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2025-11-29 19:53:37.538729: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp1wdw0oap
# 2025-11-29 19:53:37.539540: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2025-11-29 19:53:37.539554: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp1wdw0oap
# 2025-11-29 19:53:37.543441: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2025-11-29 19:53:37.597463: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp1wdw0oap
# 2025-11-29 19:53:37.606950: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 68251 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# 3072

# %% [markdown]
# ### 2. Compare Model Performance
#
# To prove these models are accurate even after conversion and quantization, we'll compare their predictions and loss on our test dataset.
#
# **Helper functions**
#
# We define the `predict` (for predictions) and `evaluate` (for loss) functions for TFLite models. *Note: These are already included in a TF model, but not in  a TFLite model.*

# %%
def predict_tflite(tflite_model, x_test):
  # Prepare the test data
  x_test_ = x_test.copy()
  x_test_ = x_test_.reshape((x_test.size, 1))
  x_test_ = x_test_.astype(np.float32)

  # Initialize the TFLite interpreter (FIXED: removed deprecated parameter)
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    x_test_ = x_test_ / input_scale + input_zero_point
    x_test_ = x_test_.astype(input_details["dtype"])

  # Invoke the interpreter
  y_pred = np.empty(x_test_.size, dtype=output_details["dtype"])
  for i in range(len(x_test_)):
    interpreter.set_tensor(input_details["index"], [x_test_[i]])
    interpreter.invoke()
    # FIXED: properly extract scalar from array
    y_pred[i] = interpreter.get_tensor(output_details["index"]).item()

  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    y_pred = y_pred.astype(np.float32)
    y_pred = (y_pred - output_zero_point) * output_scale

  return y_pred

def evaluate_tflite(tflite_model, x_test, y_true):
  global model
  y_pred = predict_tflite(tflite_model, x_test)
  loss_function = tf.keras.losses.get(model.loss)
  loss = loss_function(y_true, y_pred).numpy()
  return loss

# %% [markdown]
# **1. Predictions**

# %%
# Calculate predictions
y_test_pred_tf = model.predict(x_test)
y_test_pred_no_quant_tflite = predict_tflite(model_no_quant_tflite, x_test)
y_test_pred_tflite = predict_tflite(model_tflite, x_test)
# Out:
# 25/25 [==============================] - 0s 2ms/step

# %%
# Compare predictions
plt.clf()
plt.title('Comparison of various models against actual values')
plt.plot(x_test, y_test, 'bo', label='Actual values')
plt.plot(x_test, y_test_pred_tf, 'ro', label='TF predictions')
plt.plot(x_test, y_test_pred_no_quant_tflite, 'bx', label='TFLite predictions')
plt.plot(x_test, y_test_pred_tflite, 'gx', label='TFLite quantized predictions')
plt.legend()
plt.show()

# %% [markdown]
# **2. Loss (MSE/Mean Squared Error)**

# %%
# Calculate loss
loss_tf, _ = model.evaluate(x_test, y_test, verbose=0)
loss_no_quant_tflite = evaluate_tflite(model_no_quant_tflite, x_test, y_test)
loss_tflite = evaluate_tflite(model_tflite, x_test, y_test)

# %%
# Compare loss
df = pd.DataFrame.from_records(
    [["TensorFlow", loss_tf],
     ["TensorFlow Lite", loss_no_quant_tflite],
     ["TensorFlow Lite Quantized", loss_tflite]],
     columns = ["Model", "Loss/MSE"], index="Model").round(4)
df
# Out:
#                            Loss/MSE
# Model
# TensorFlow                   0.4861
# TensorFlow Lite              0.4861
# TensorFlow Lite Quantized    0.4881

# %% [markdown]
# **3. Size**

# %%
# Calculate size
size_tf = os.path.getsize(MODEL_TF)
size_no_quant_tflite = os.path.getsize(MODEL_NO_QUANT_TFLITE)
size_tflite = os.path.getsize(MODEL_TFLITE)

# %%
# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                   Size
# Model
# TensorFlow                 29774 bytes
# TensorFlow Lite            3228 bytes   (reduced by 26546 bytes)
# TensorFlow Lite Quantized   3072 bytes    (reduced by 156 bytes)

# %% [markdown]
# **Summary**

# %% [markdown]
# We can see from the predictions (graph) and loss (table) that the original TF model, the TFLite model, and the quantized TFLite model are all close enough to be indistinguishable - even though they differ in size (table). This implies that the quantized (smallest) model is ready to use!
#
# *Note: The quantized (integer) TFLite model is just 300 bytes smaller than the original (float) TFLite model - a tiny reduction in size! This is because the model is already so small that quantization has little effect. Complex models with more weights, can have upto a 4x reduction in size!*

# %% [markdown]
# ## Generate a TensorFlow Lite for Microcontrollers Model
# Convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers.

# %%
# Install xxd if it is not available
# !apt-get update && apt-get -qq install xxd
# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}
# Out:
# Reading package lists... Done
# E: List directory /var/lib/apt/lists/partial is missing. - Acquire (13: Permission denied)

# %% [markdown]
# ## Deploy to a Microcontroller
#
# Follow the instructions in the [hello_world](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world) README.md for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview) to deploy this model on a specific microcontroller.
#
# **Reference Model:** If you have not modified this notebook, you can follow the instructions as is, to deploy the model. Refer to the [`hello_world/train/models`](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/models) directory to access the models generated in this notebook.
#
# **New Model:** If you have generated a new model, then update the values assigned to the variables defined in [`hello_world/model.cc`](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/model.cc) with values displayed after running the following cell.

# %%
# Print the C source file
# !cat {MODEL_TFLITE_MICRO}
# Out:
# unsigned char g_model[] = {
#   0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x14, 0x00, 0x20, 0x00,
#   0x1c, 0x00, 0x18, 0x00, 0x14, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x14, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x88, 0x00, 0x00, 0x00, 0xe0, 0x00, 0x00, 0x00, 0xac, 0x03, 0x00, 0x00,
#   0xbc, 0x03, 0x00, 0x00, 0x78, 0x0b, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x02, 0xfc, 0xff, 0xff,
#   0x0c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f,
#   0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x94, 0xff, 0xff, 0xff, 0x0b, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73,
#   0x65, 0x5f, 0x32, 0x39, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xda, 0xfc, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x5f, 0x31, 0x32,
#   0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xdc, 0xff, 0xff, 0xff, 0x0e, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x13, 0x00, 0x00, 0x00, 0x43, 0x4f, 0x4e, 0x56,
#   0x45, 0x52, 0x53, 0x49, 0x4f, 0x4e, 0x5f, 0x4d, 0x45, 0x54, 0x41, 0x44,
#   0x41, 0x54, 0x41, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74,
#   0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0xc8, 0x02, 0x00, 0x00, 0xc0, 0x02, 0x00, 0x00,
#   0xac, 0x02, 0x00, 0x00, 0x84, 0x02, 0x00, 0x00, 0x34, 0x02, 0x00, 0x00,
#   0x24, 0x01, 0x00, 0x00, 0xd4, 0x00, 0x00, 0x00, 0xb4, 0x00, 0x00, 0x00,
#   0xac, 0x00, 0x00, 0x00, 0xa4, 0x00, 0x00, 0x00, 0x9c, 0x00, 0x00, 0x00,
#   0x94, 0x00, 0x00, 0x00, 0x8c, 0x00, 0x00, 0x00, 0x6c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x8e, 0xfd, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x58, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0e, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x28, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xeb, 0x03, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x10, 0x00, 0x0c, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x0a, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x32, 0x2e, 0x31, 0x34, 0x2e, 0x30, 0x00, 0x00, 0xf2, 0xfd, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x31, 0x2e, 0x31, 0x34,
#   0x2e, 0x30, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x50, 0xf6, 0xff, 0xff, 0x54, 0xf6, 0xff, 0xff, 0x58, 0xf6, 0xff, 0xff,
#   0x5c, 0xf6, 0xff, 0xff, 0x60, 0xf6, 0xff, 0xff, 0x22, 0xfe, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0xd0, 0x77, 0xc4, 0xaa,
#   0xd8, 0xd9, 0x99, 0x5e, 0x95, 0x87, 0x76, 0x28, 0xd0, 0x56, 0x81, 0xba,
#   0x3e, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x3d, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x78, 0x2a, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0xdf, 0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x37, 0xf9, 0xff, 0xff, 0xc6, 0x04, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x29, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x8a, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x00, 0x01, 0x00, 0x00, 0xf2, 0x0c, 0x18, 0x10, 0xed, 0xe3, 0x10, 0x05,
#   0x0f, 0xf1, 0xf8, 0x02, 0xfd, 0xf0, 0xf0, 0x05, 0xf3, 0xe8, 0xee, 0xfa,
#   0xf3, 0x0d, 0x14, 0xfa, 0xf3, 0xe5, 0x0f, 0xf1, 0xff, 0xfd, 0xfe, 0xf4,
#   0x1a, 0x04, 0x09, 0x0c, 0x3e, 0x11, 0x1b, 0x08, 0xfa, 0xeb, 0xf8, 0xfe,
#   0x0d, 0x14, 0xeb, 0x0c, 0xed, 0x0c, 0x11, 0xf0, 0xee, 0xff, 0xe7, 0x03,
#   0x10, 0x02, 0x13, 0xf7, 0x13, 0x11, 0xf0, 0x1a, 0xe9, 0xec, 0xe4, 0x1c,
#   0xfa, 0x14, 0x02, 0x15, 0xf2, 0x00, 0xec, 0x01, 0x06, 0x0e, 0xf6, 0xe7,
#   0xf8, 0x13, 0xfd, 0xee, 0x30, 0x12, 0x08, 0x13, 0x05, 0x0e, 0xf3, 0x1c,
#   0xe6, 0x19, 0x02, 0xed, 0xe6, 0xe9, 0xed, 0xe8, 0xf2, 0xf2, 0xef, 0xf1,
#   0xf0, 0xf6, 0x09, 0xfc, 0x0f, 0xfa, 0x15, 0xeb, 0x0e, 0xf2, 0x0b, 0xe8,
#   0xf9, 0x00, 0x0d, 0x05, 0xed, 0x02, 0x04, 0xff, 0x0e, 0xf1, 0x02, 0x18,
#   0x1a, 0xf6, 0xe9, 0xf9, 0xef, 0x1b, 0xff, 0xfb, 0x06, 0x02, 0xf7, 0xfc,
#   0xe4, 0x0f, 0xf4, 0x18, 0x04, 0xf2, 0x15, 0x15, 0xfe, 0x1a, 0x07, 0x05,
#   0x15, 0xe7, 0x0d, 0xe6, 0x19, 0xe8, 0xf4, 0x0d, 0x12, 0xee, 0xfc, 0xef,
#   0x2d, 0x0e, 0xe8, 0xef, 0x0d, 0x18, 0xad, 0x2b, 0x0c, 0xc0, 0x0f, 0x14,
#   0x03, 0xf4, 0x0f, 0x15, 0x00, 0x05, 0xed, 0x14, 0xf0, 0xfb, 0x00, 0xec,
#   0xfa, 0x0b, 0xfa, 0x0d, 0xeb, 0xbc, 0x03, 0xf0, 0x1c, 0xf8, 0x07, 0x81,
#   0xff, 0xfb, 0x52, 0x22, 0x16, 0xff, 0x12, 0xf9, 0xfa, 0xe5, 0x17, 0xfb,
#   0x45, 0x03, 0xe6, 0x0c, 0x07, 0x13, 0xee, 0xf7, 0x13, 0x0c, 0xf3, 0xfa,
#   0xf0, 0x04, 0xf8, 0xf9, 0xe9, 0xe5, 0x0e, 0x12, 0x08, 0x0e, 0x0d, 0x0e,
#   0xfd, 0x04, 0xf5, 0x19, 0x11, 0xf7, 0xe6, 0x1a, 0xe9, 0x16, 0xe5, 0x18,
#   0xfe, 0x08, 0x1d, 0xf0, 0xf9, 0x0c, 0xf8, 0xe4, 0x96, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0xf4, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x4a, 0x03, 0x00, 0x00, 0xb2, 0xfd, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0xda, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0xf7, 0x0a, 0x00, 0x00, 0x09, 0xff, 0xff, 0xff, 0xcf, 0x04, 0x00, 0x00,
#   0xfc, 0x05, 0x00, 0x00, 0xdc, 0xfd, 0xff, 0xff, 0x18, 0xff, 0xff, 0xff,
#   0xe2, 0xff, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x06, 0x02, 0x0f, 0xda, 0x24, 0x27, 0x02, 0xdd, 0x27, 0x01, 0x76, 0xfd,
#   0x81, 0x97, 0xdb, 0xf1, 0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x6f, 0x03, 0x00, 0x00, 0x58, 0xf8, 0xff, 0xff, 0x5c, 0xf8, 0xff, 0xff,
#   0x0f, 0x00, 0x00, 0x00, 0x4d, 0x4c, 0x49, 0x52, 0x20, 0x43, 0x6f, 0x6e,
#   0x76, 0x65, 0x72, 0x74, 0x65, 0x64, 0x2e, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x14, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x40, 0x01, 0x00, 0x00,
#   0x44, 0x01, 0x00, 0x00, 0x48, 0x01, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x6d, 0x61, 0x69, 0x6e, 0x00, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
#   0x08, 0x01, 0x00, 0x00, 0xb8, 0x00, 0x00, 0x00, 0x6c, 0x00, 0x00, 0x00,
#   0x34, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0a, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x92, 0xff, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x08, 0x10, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x0c, 0xf9, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xc6, 0xff, 0xff, 0xff,
#   0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x14, 0x00, 0x00, 0x00,
#   0x18, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xb6, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x01, 0x01, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x1a, 0x00, 0x14, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x0b, 0x00, 0x04, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x1c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x1c, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00,
#   0x08, 0x00, 0x07, 0x00, 0x06, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01,
#   0x01, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x07, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0a, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0xec, 0x05, 0x00, 0x00, 0x48, 0x05, 0x00, 0x00, 0xc0, 0x04, 0x00, 0x00,
#   0x44, 0x04, 0x00, 0x00, 0xd0, 0x03, 0x00, 0x00, 0x54, 0x03, 0x00, 0x00,
#   0xe0, 0x02, 0x00, 0x00, 0x6c, 0x02, 0x00, 0x00, 0x98, 0x01, 0x00, 0x00,
#   0xdc, 0x00, 0x00, 0x00, 0x60, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x5a, 0xfa, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00,
#   0x1c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x34, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0x01, 0x00, 0x00, 0x00, 0x44, 0xfa, 0xff, 0xff, 0x19, 0x00, 0x00, 0x00,
#   0x53, 0x74, 0x61, 0x74, 0x65, 0x66, 0x75, 0x6c, 0x50, 0x61, 0x72, 0x74,
#   0x69, 0x74, 0x69, 0x6f, 0x6e, 0x65, 0x64, 0x43, 0x61, 0x6c, 0x6c, 0x3a,
#   0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x16, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01,
#   0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x0b, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x50, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
#   0x4c, 0xfb, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xeb, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x01, 0x00, 0x00, 0x00, 0x58, 0x3c, 0x3e, 0x3c, 0x1a, 0x00, 0x00, 0x00,
#   0x53, 0x74, 0x61, 0x74, 0x65, 0x66, 0x75, 0x6c, 0x50, 0x61, 0x72, 0x74,
#   0x69, 0x74, 0x69, 0x6f, 0x6e, 0x65, 0x64, 0x43, 0x61, 0x6c, 0x6c, 0x3a,
#   0x30, 0x31, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x8e, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01,
#   0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x90, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x10, 0x00, 0x00, 0x00,
#   0xc4, 0xfb, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x01, 0x00, 0x00, 0x00, 0x58, 0xbc, 0xaf, 0x3c, 0x58, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31,
#   0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x38, 0x2f, 0x4d,
#   0x61, 0x74, 0x4d, 0x75, 0x6c, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e,
#   0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73,
#   0x65, 0x5f, 0x32, 0x38, 0x2f, 0x52, 0x65, 0x6c, 0x75, 0x3b, 0x73, 0x65,
#   0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f,
#   0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x38, 0x2f, 0x42, 0x69, 0x61,
#   0x73, 0x41, 0x64, 0x64, 0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x46, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x01, 0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x3c, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x90, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0x10, 0x00, 0x00, 0x00, 0x7c, 0xfc, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff,
#   0xff, 0xff, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00, 0x75, 0x32, 0xd6, 0x3c,
#   0x58, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f,
#   0x32, 0x37, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x3b, 0x73, 0x65,
#   0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f,
#   0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x37, 0x2f, 0x52, 0x65, 0x6c,
#   0x75, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c,
#   0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x37,
#   0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x00, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x16, 0x00, 0x20, 0x00, 0x1c, 0x00, 0x1b, 0x00, 0x14, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x00, 0x07, 0x00,
#   0x16, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x18, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x09, 0x48, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00, 0x4c, 0xfd, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xbf, 0x57, 0x49, 0x3d, 0x0c, 0x00, 0x00, 0x00,
#   0x74, 0x66, 0x6c, 0x2e, 0x71, 0x75, 0x61, 0x6e, 0x74, 0x69, 0x7a, 0x65,
#   0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xc2, 0xfd, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01,
#   0x14, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x09, 0x4c, 0x00, 0x00, 0x00, 0xac, 0xfd, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xbf, 0x05, 0x94, 0x3b, 0x1d, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31,
#   0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x37, 0x2f, 0x4d,
#   0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x32, 0xfe, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02, 0x58, 0x00, 0x00, 0x00,
#   0x1c, 0xfe, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x7f, 0xd6, 0x68, 0x39, 0x2d, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31,
#   0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x32, 0x37, 0x2f, 0x42,
#   0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64, 0x56,
#   0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0xaa, 0xfe, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x4c, 0x00, 0x00, 0x00,
#   0x94, 0xfe, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xe0, 0xc1, 0x78, 0x3c,
#   0x1d, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f,
#   0x32, 0x38, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x1a, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00,
#   0x30, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02,
#   0x58, 0x00, 0x00, 0x00, 0x04, 0xff, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x19, 0x23, 0xd0, 0x39,
#   0x2d, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f,
#   0x32, 0x38, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x2f, 0x52,
#   0x65, 0x61, 0x64, 0x56, 0x61, 0x72, 0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f,
#   0x70, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x92, 0xff, 0xff, 0xff, 0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00,
#   0x30, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x48, 0x00, 0x00, 0x00, 0x7c, 0xff, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x59, 0x84, 0x7b, 0x3c,
#   0x1d, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f,
#   0x32, 0x39, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x16, 0x00, 0x1c, 0x00, 0x18, 0x00, 0x17, 0x00, 0x10, 0x00,
#   0x0c, 0x00, 0x08, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x07, 0x00,
#   0x16, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x20, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02,
#   0x68, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x84, 0xa8, 0xac, 0x39, 0x2d, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x31, 0x2f, 0x64, 0x65,
#   0x6e, 0x73, 0x65, 0x5f, 0x32, 0x39, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41,
#   0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64, 0x56, 0x61, 0x72, 0x69, 0x61,
#   0x62, 0x6c, 0x65, 0x4f, 0x70, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x16, 0x00, 0x1c, 0x00, 0x18, 0x00,
#   0x00, 0x00, 0x14, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x07, 0x00, 0x16, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01,
#   0x14, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x38, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x1a, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76,
#   0x69, 0x6e, 0x67, 0x5f, 0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x5f,
#   0x69, 0x6e, 0x70, 0x75, 0x74, 0x5f, 0x31, 0x32, 0x3a, 0x30, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xf0, 0xff, 0xff, 0xff, 0x06, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x0c, 0x00, 0x10, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x0c, 0x00, 0x0c, 0x00, 0x0b, 0x00, 0x00, 0x00, 0x00, 0x00, 0x04, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x72, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x72
# };
# unsigned int g_model_len = 3072;

# %%
# Diagnostics: quantization params and sine comparison
import numpy as np, math, tensorflow as tf
import matplotlib.pyplot as plt

def get_io_quant_params(tflite_model):
    interpreter = tf.lite.Interpreter(model_content=tflite_model)
    interpreter.allocate_tensors()
    in_det = interpreter.get_input_details()[0]
    out_det = interpreter.get_output_details()[0]
    return (in_det['quantization'], in_det['dtype']), (out_det['quantization'], out_det['dtype'])

# Build a dense sweep over one full sine period
x_dense = np.linspace(0.0, 2*math.pi, 256, dtype=np.float32)
y_dense_true = np.sin(x_dense).astype(np.float32)

(in_q, in_dtype), (out_q, out_dtype) = get_io_quant_params(model_tflite)
print('Input quantization:', in_q, 'dtype:', in_dtype)
print('Output quantization:', out_q, 'dtype:', out_dtype)

y_dense_tf = model.predict(x_dense)
y_dense_tflite = predict_tflite(model_tflite, x_dense)
y_dense_noq = predict_tflite(model_no_quant_tflite, x_dense)

print('Stats TF: min', float(np.min(y_dense_tf)), 'max', float(np.max(y_dense_tf)))
print('Stats TFLite int8: min', float(np.min(y_dense_tflite)), 'max', float(np.max(y_dense_tflite)))
print('Stats TFLite float: min', float(np.min(y_dense_noq)), 'max', float(np.max(y_dense_noq)))

plt.figure(figsize=(10,5))
plt.plot(x_dense, y_dense_true, 'k-', label='sin(x)')
plt.plot(x_dense, y_dense_tf, 'r--', label='TF')
plt.plot(x_dense, y_dense_noq, 'b-.', label='TFLite float')
plt.plot(x_dense, y_dense_tflite, 'g:', label='TFLite int8')
plt.legend(); plt.title('Dense sweep comparison'); plt.show()
# Out:
# Input quantization: (0.0, 0) dtype: <class 'numpy.float32'>
# Output quantization: (0.0, 0) dtype: <class 'numpy.float32'>
# 8/8 [==============================] - 0s 3ms/step
# Stats TF: min -0.7424911260604858 max 1.7228957414627075
# Stats TFLite int8: min -0.7082750797271729 max 1.718437910079956
# Stats TFLite float: min -0.7424915432929993 max 1.7228949069976807
